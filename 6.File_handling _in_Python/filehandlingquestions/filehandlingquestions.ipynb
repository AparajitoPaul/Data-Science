# %% [markdown]
# # Module: File Handling Assignments
# ## Lesson: File Handling and Operations

# %% [markdown]
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.

# %%
def read_content(file_path):
    with open(file_path,'r') as file:
        content=file.read()
        print(content)

file_path='sample.txt'
read_content(file_path)
# Out:
# Hi, this file is a text file created exclusively for the assignment questions
# This can be modified throughout the assignment notebook as we go ahead question by question
# This can be fun!

# %% [markdown]
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.

# %%
list1=['Paul','Roy','Simba','Simran']

def write_list(lst):
    with open("output.txt",'w') as file:
        for i in lst:
            file.write(f"{i}\n")

write_list(list1)

# %% [markdown]
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `sample.txt` to a new file named `destination.txt`.

# %%
def copy_file(source, destination):
    with open(source, 'r') as src:
        with open(destination, 'w') as dest:
            dest.write(src.read())

# Test
copy_file('sample.txt','output1.txt')

# %% [markdown]
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `sample.txt`.

# %%
def str_append(file_path,strg):
    with open(file_path,'a') as file:
        file.write(strg+'\n')
str_append("sample.txt","this line was added by appending function")

# %% [markdown]
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `sample.txt` and returns the number of words in the file.

# %%
def word_count(file_path):
    with open(file_path,'r') as file:
        lines=file.readlines()
        wc=sum(len(line.split()) for line in lines)
        return wc

# %%
word_count('sample.txt')
# Out:
# 39

# %% [markdown]
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `sample.txt` with another word.

# %%
def replace_word(file_path,old_word,new_word):
    a=[]
    with open(file_path,'r') as file:
        content=file.read()
    content=content.replace(old_word,new_word)

    with open(file_path,'w')as file:
        file.write(content)

# %%
#Test
replace_word('sample.txt','This','It')

# %% [markdown]
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.

# %%
def read_reverse(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()
    for line in reversed(lines):
        print(line.strip())

# %%
# Test
read_reverse('sample.txt')
# Out:
# this line was added by appending function
# It can be fun!
# It can be modified throughout the assignment notebook as we go ahead question by question
# Hi, this file is a text file created exclusively for the assignment questions

# %% [markdown]
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `sample.txt` and returns the number of lines, words, and characters in the file.

# %%
def count_file(file_path):
    with open(file_path,'r') as file:
        lines=file.readlines()
        line_count=len(lines)
        word_count=sum(len(line.split()) for line in lines)
        char_count=sum(len(line) for line in lines)
        return (line_count,word_count,char_count)

# %%
lc,wc,cc=count_file('sample.txt')
print(f"LINE COUNT:{lc}\nWORD COUNT:{wc}\nCHARECTER COUNT:{cc}")
# Out:
# LINE COUNT:4
# WORD COUNT:39
# CHARECTER COUNT:225

# %% [markdown]
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %%
def merge_files(file_list, output_file):
    with open(output_file, 'w') as outfile:
        for fname in file_list:
            with open(fname, 'r') as infile:
                outfile.write(infile.read() + '\n')

# %%
# Test
merge_files(['sample.txt','output.txt'],'merged.txt')

# %% [markdown]
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.

# %%
def split_file(filename, lines_per_file):
    with open(filename, 'r') as file:
        lines = file.readlines()
    for i in range(0, len(lines), lines_per_file):
        with open(f'{filename}_part{i//lines_per_file + 1}.txt', 'w') as part_file:
            part_file.writelines(lines[i:i + lines_per_file])

# %% [markdown]
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.

# %%
import datetime

def log_message(message, filename='activity.log'):
    timestamp = datetime.datetime.now().isoformat()
    with open(filename, 'a') as file:
        file.write(f'[{timestamp}] {message}\n')

# %%
# Test
log_message('This is a log message.')

# %% [markdown]
# ### Assignment 12: Binary File Operations
#
# Write a function that reads a binary file named `sample.bin` and writes its contents to another binary file named `copy_sample.bin`.

# %%
def copy_binary_file(source, destination):
    with open(source, 'rb') as src:
        with open(destination, 'wb') as dest:
            dest.write(src.read())

# %%
# Test
copy_binary_file('sample.bin','copy_sample.bin')

# %% [markdown]
# ### Assignment 13: CSV File Operations
#
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.

# %%
import csv

def read_csv_as_dicts(filename):
    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        return list(reader)

# %%
# Test
print(read_csv_as_dicts('data.csv'))
# Out:
# [{'\ufeffAsish': 'Brendon', '90': '85'}, {'\ufeffAsish': 'Chandan', '90': '93'}, {'\ufeffAsish': 'Damien', '90': '76'}]

# %% [markdown]
# ### Assignment 14: JSON File Operations
#
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.

# %%
import json

def read_json(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
        return data

# %%
# Test
print(read_json('data.json'))
# Out:
# {'name': 'Aparajito', 'age': 31, 'city': 'Bangalore', 'skills': ['Python', 'SQL', 'Power BI']}

# %% [markdown]
# ### Assignment 15: File Permission Handling
#
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.

# %%
def read_protected_file(filename):
    try:
        with open(filename, 'r') as file:
            print(file.read())
    except PermissionError as e:
        print(f"Permission error: {e}")
